# %%
import Sastrawi as sw
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import pandas as pd

factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
data = pd.read_csv("data/id_kompetensi_flag_new.csv", sep=";")

# %%
data['KOMPETENSI'] = data.loc[:,'KOMPETENSI'].str.lower()
data['KOMPETENSI'] = data.loc[:,'KOMPETENSI'].replace()
data = data.replace(regex={'KOMPETENSI': r'[^0-9a-zA-Z]+'}, value=' ')
new_data = data.copy()
new_data
# Out:
#                                            ID_PEGAWAI  \
# 0                        198610172010122008_Wiliyanti
# 1                            198408302010122002_Intan
# 2                    198501282010122002_WindaMayasari
# 3       198407242010122002_InnaYoanaSariTariganSibero
# 4            199207152015021002_PandhuSiddiqWicaksono
# ...                                               ...
# 115840                199102102013101001_ErickFirdaus
# 115841                     198606022010122005_Suryani
# 115842         199012182013101001_AchmadGelarTrinanda
# 115843             198507132010122001_EritaYuliastuti
# 115844                 198503262010122006_Arientawati
#
#                                                KOMPETENSI       FLAG
# 0                     sprin plh kepala kptik bmn semarang  DISPOSISI
# 1       penyampaian surat edaran menteri keuangan nomo...  DISPOSISI
# 2             penyampaian surat keterangan tugas tambahan  DISPOSISI
# 3       penyampaian surat edaran menteri keuangan nomo...  DISPOSISI
# 4                             permohonan perbaikan plafon  DISPOSISI
# ...                                                   ...        ...
# 115840  sprin plh kepala bidang manajemen layanan tik ...  DISPOSISI
# 115841  efisiensi penggunaan kertas dan toner tinta pr...  DISPOSISI
# 115842  sprin plh kepala bidang manajemen layanan tik ...  DISPOSISI
# 115843  asistensi penyusunan uraian jabatan bagi jabat...  DISPOSISI
# 115844  efisiensi penggunaan kertas dan toner tinta pr...  DISPOSISI
#
# [115845 rows x 3 columns]

# %%
list_data = list(new_data.loc[:, 'KOMPETENSI'])
list_data
# Out:
# ['sprin plh kepala kptik bmn semarang',
#  'penyampaian surat edaran menteri keuangan nomor se 29 mk 1 2019 tentang pelaporan dialog kinerja individu periode i tahun 2020 di lingkungan kementerian keuangan',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyampaian surat edaran menteri keuangan nomor se 29 mk 1 2019 tentang pelaporan dialog kinerja individu periode i tahun 2020 di lingkungan kementerian keuangan',
#  'permohonan perbaikan plafon',
#  'penyampaian laporan hasil audit eksternal configuration management database cmdb pusintek tahun 2019',
#  'penyampaian tim teknis dja untuk kegiatan akhir tahun 2019',
#  'strategi percepatan pelaksanaan anggaran ta 2020',
#  'penyampaian tim teknis dja untuk kegiatan akhir tahun 2019',
#  'surat tugas memeberikan layanan dukungan dalam kunjungan menteri keuangan ri ke jawa timur',
#  'penyampaian laporan hasil audit eksternal configuration management database cmdb pusintek tahun 2019',
#  'permintaan usulan pagu indikatif ta 2021 lingkup eselon i sekretariat jenderal kemenkeu',
#  'penyampaian laporan hasil audit eksternal configuration management database cmdb pusintek tahun 2019',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian laporan hasil audit eksternal configuration management database cmdb pusintek tahun 2019',
#  'permintaan usulan pagu indikatif ta 2021 lingkup eselon i sekretariat jenderal kemenkeu',
#  'penyampaian laporan hasil audit eksternal configuration management database cmdb pusintek tahun 2019',
#  'pembayaran uang persediaan pada awal tahun anggaran 2020',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian laporan hasil audit eksternal configuration management database cmdb pusintek tahun 2019',
#  'penyampaian laporan hasil audit eksternal configuration management database cmdb pusintek tahun 2019',
#  'pembayaran uang persediaan pada awal tahun anggaran 2020',
#  'penyampaian hasil rapat cab selasa',
#  'penawaran rental tanaman di kantor kemenkeu pusintek di jalan dr wahidin no 1 jakarta indonesia untuk tahun anggaran 2020',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian surat keterangan tugas tambahan',
#  'sprin plh kepala bidang manajemen layanan tik',
#  'permohonan penunjukan uic utama is rbtk 2020 layanan digital kemenkeu',
#  'undangan pembahasan pelaksanaan abk tahun 2020',
#  'sprin plh kepala bidang manajemen layanan tik',
#  'permohonan penunjukan uic utama is rbtk 2020 layanan digital kemenkeu',
#  'himbauan penyampaian laporan harta kekayaan penyelenggara negara lhkpn ',
#  'sprin plh kepala kptik bmn semarang',
#  'sprin plh kepala kantor pengelolaan tik dan bmn semarang',
#  'himbauan penyampaian laporan harta kekayaan penyelenggara negara lhkpn ',
#  'penyampaian surat keterangan tugas tambahan',
#  'sprin plh kepala kantor pengelolaan tik dan bmn semarang',
#  'penyampaian surat keterangan tugas tambahan',
#  'permohonan penetapan plh ',
#  'permohonan perbaikan fasilitas gedung bdk makassar',
#  'surat perintah',
#  'penyampaian kak',
#  'surat perintah',
#  'penyampaian rancangan keputusan kepala pusintek tentang pemberian mandat penandatanganan standar operasional prosedur sop di lingkungan pusintek',
#  'himbauan penyampaian laporan harta kekayaan penyelenggara negara lhkpn ',
#  'permintaan snack rapat koordinasi lanjutan api nadine dengan aplikasi inspektorat jenderal',
#  'himbauan penyampaian laporan harta kekayaan penyelenggara negara lhkpn ',
#  'undangan pembahasan pelaksanaan abk tahun 2020',
#  'perubahan manfaat program',
#  'penyampaian surat keterangan tugas tambahan',
#  'undangan dialog kinerja organisasi dko periode triwulan iv tahun 2019',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyampaian surat keterangan tugas tambahan',
#  'permintaan snack rapat koordinasi lanjutan api nadine dengan aplikasi inspektorat jenderal',
#  'penyampaian surat keterangan tugas tambahan',
#  'perubahan undangan dialog kinerja organisasi dko periode triwulan iv tahun 2019',
#  'penyampaian surat keterangan tugas tambahan',
#  'perubahan undangan dialog kinerja organisasi dko periode triwulan iv tahun 2019',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyampaian informasi pengembangan sistem informasi lembaga national single window lnsw tahun 2021',
#  'penyampaian laporan kunjungan implementasi big data kementerian keuangan ke komisi pemberantasan korupsi',
#  'penyampaian laporan kunjungan implementasi big data kementerian keuangan ke komisi pemberantasan korupsi',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyampaian laporan kunjungan implementasi big data kementerian keuangan ke komisi pemberantasan korupsi',
#  'surat perintah kerja lembur bidang manajemen layanan tik desember 2019',
#  'penyampaian laporan kunjungan implementasi big data kementerian keuangan ke komisi pemberantasan korupsi',
#  'surat perintah kerja lembur bidang manajemen layanan tik desember 2019',
#  'penyampaian laporan kunjungan implementasi big data kementerian keuangan ke komisi pemberantasan korupsi',
#  'penyampaian laporan kunjungan implementasi big data kementerian keuangan ke komisi pemberantasan korupsi',
#  'surat perintah kerja lembur bidang manajemen layanan tik desember 2019',
#  'penyampaian laporan kunjungan implementasi big data kementerian keuangan ke komisi pemberantasan korupsi',
#  'surat perintah kerja lembur bidang manajemen layanan tik desember 2019',
#  'penyampaian laporan kunjungan implementasi big data kementerian keuangan ke komisi pemberantasan korupsi',
#  'permintaan snack rapat koordinasi lanjutan api nadine dengan aplikasi inspektorat jenderal',
#  'surat perintah kerja lembur bidang manajemen layanan tik desember 2019',
#  'persiapan pengamanan infrastruktur dalam menghadapi akhir tahun 2019',
#  'laporan hasil uji kerentanan vulnerability test aplikasi e kemenkeu p1',
#  'surat perintah kerja lembur bidang manajemen layanan tik desember 2019',
#  'laporan hasil uji kerentanan vulnerability test aplikasi e kemenkeu p1',
#  'surat perintah kerja lembur bidang manajemen layanan tik desember 2019',
#  'permintaan akses data bps yang tersedia di pusintek',
#  'surat perintah kerja lembur bidang manajemen layanan tik desember 2019',
#  'permintaan snack rapat koordinasi lanjutan api nadine dengan aplikasi inspektorat jenderal',
#  'surat perintah kerja lembur bidang manajemen layanan tik desember 2019',
#  'surat tugas rdk pembahasan pengembangan aplikasi sprint',
#  'permintaan akses data bps yang tersedia di pusintek',
#  'permohonan penyediaan konsumsi dalam rangka kegiatan penutupan pekerjaan pengadaan renovasi power house kementerian keuangan tahun anggaran 2019',
#  'surat tugas rdk pembahasan pengembangan aplikasi sprint',
#  'permintaan akses data badan pusat statistik bps terkait stranas pk',
#  'undangan diskusi penggunaan aplikasi manageengine',
#  'penyampaian hasil rapat cab selasa',
#  'laporan hasil uji kerentanan vulnerability test aplikasi pnbp lelang p2',
#  'penyampaian hasil rapat cab selasa',
#  'permintaan akses data badan pusat statistik bps terkait stranas pk',
#  'penyampaian hasil rapat cab selasa',
#  'permintaan akses data badan pusat statistik bps terkait stranas pk',
#  'permohonan penyediaan konsumsi dalam rangka kegiatan penutupan pekerjaan pengadaan renovasi power house kementerian keuangan tahun anggaran 2019',
#  'penyampaian hasil rapat cab selasa',
#  'permintaan usulan pagu indikatif ta 2021 lingkup eselon i sekretariat jenderal kemenkeu',
#  'penyampaian hasil rapat cab selasa',
#  'permohonan penyediaan konsumsi dalam rangka kegiatan penutupan pekerjaan pengadaan renovasi power house kementerian keuangan tahun anggaran 2019',
#  'penyampaian hasil rapat cab selasa',
#  'permohonan penyediaan konsumsi dalam rangka kegiatan evaluasi pekerjaan pengadaan renovasi power house kementerian keuangan tahun anggaran 2019',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab selasa',
#  'permintaan usulan pagu indikatif ta 2021 lingkup eselon i sekretariat jenderal kemenkeu',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian rancangan keputusan kepala pusintek tentang pemberian mandat penandatanganan standar operasional prosedur sop di lingkungan pusintek',
#  'undangan pembahasan pelaksanaan abk tahun 2020',
#  'permohonan penyediaan konsumsi dalam rangka kegiatan evaluasi pekerjaan pengadaan renovasi power house kementerian keuangan tahun anggaran 2019',
#  'laporan hasil uji kerentanan vulnerability test aplikasi simfoni versi 4 p1',
#  'permohonan penyediaan konsumsi dalam rangka kegiatan evaluasi pekerjaan pengadaan renovasi power house kementerian keuangan tahun anggaran 2019',
#  'penyampaian tim teknis dja untuk kegiatan akhir tahun 2019',
#  'penyampaian laporan kunjungan implementasi big data kementerian keuangan ke komisi pemberantasan korupsi',
#  'permohonan penyediaan konsumsi dalam rangka kegiatan evaluasi pekerjaan pengadaan renovasi power house kementerian keuangan tahun anggaran 2019',
#  'penyampaian laporan kunjungan implementasi big data kementerian keuangan ke komisi pemberantasan korupsi',
#  'penyampaian laporan simplifikasi pelayanan kementerian keuangan tahun 2019',
#  'penyampaian laporan simplifikasi pelayanan kementerian keuangan tahun 2019',
#  'undangan rapat koordinasi tim organisasi keamanan informasi di lingkungan sekretariat jenderal kementerian keuangan',
#  'undangan pembahasan pelaksanaan abk tahun 2020',
#  's prin plh kabid kiktik cuti tahunan plh yang ditunjuk ismail fahmi',
#  'strategi percepatan pelaksanaan anggaran ta 2020',
#  'penyampaian tim teknis dja untuk kegiatan akhir tahun 2019',
#  'permohonan penyediaan konsumsi dalam rangka kegiatan evaluasi pekerjaan pengadaan renovasi power house kementerian keuangan tahun anggaran 2019',
#  'strategi percepatan pelaksanaan anggaran ta 2020',
#  'penyampaian tim teknis dja untuk kegiatan akhir tahun 2019',
#  'permohonan penyediaan konsumsi dalam rangka kegiatan evaluasi pekerjaan pengadaan renovasi power house kementerian keuangan tahun anggaran 2019',
#  'penyampaian laporan kunjungan implementasi big data kementerian keuangan ke komisi pemberantasan korupsi',
#  'penyampaian tim teknis dja untuk kegiatan akhir tahun 2019',
#  'permohonan penyediaan konsumsi dalam rangka kegiatan penutupan pekerjaan pengadaan renovasi power house kementerian keuangan tahun anggaran 2019',
#  'undangan seminar teknologi infomasi pada lnsw artificial intelligence untuk membantu pemerintahan dan revolusi industri 4 0',
#  'penyampaian tim teknis dja untuk kegiatan akhir tahun 2019',
#  'undangan pembahasan desain pembelajaran program pembelajaran information security awareness',
#  'penyampaian tim teknis dja untuk kegiatan akhir tahun 2019',
#  'undangan dialog kinerja organisasi',
#  'penyampaian tim teknis dja untuk kegiatan akhir tahun 2019',
#  'strategi percepatan pelaksanaan anggaran ta 2020',
#  'penyampaian tim teknis dja untuk kegiatan akhir tahun 2019',
#  'strategi percepatan pelaksanaan anggaran ta 2020',
#  'penyampaian progress capaian kinerja sampai dengan november 2019',
#  'penyampaian ringkasan rapat akhir tahun tik kementerian keuangan tahun 2019',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyampaian ringkasan rapat akhir tahun tik kementerian keuangan tahun 2019',
#  'penyampaian hasil pemilihan penyedia jasa paket pengadaan annual technical support ats software dan appliance tahun anggaran 2020',
#  'penyampaian tim teknis dja untuk kegiatan akhir tahun 2019',
#  'penyampaian ringkasan rapat akhir tahun tik kementerian keuangan tahun 2019',
#  'rencana pengelolaan kinerja pusintek triwulan iv tahun 2019',
#  'penyampaian tim teknis dja untuk kegiatan akhir tahun 2019',
#  'penyampaian laporan bulanan penerbitan spm periode desember 2019',
#  'laporan hasil uji beban performance test aplikasi sakti web djpb ke 2',
#  'penyampaian laporan bulanan penerbitan spm periode desember 2019',
#  'permohonan penunjukan uic utama is rbtk 2020 layanan digital kemenkeu',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyampaian laporan bulanan penerbitan spm periode desember 2019',
#  'penyampaian surat keterangan tugas tambahan',
#  'permohonan penarikan link dan pembukaan interkoneksi host to host pt indomarco pristama ke sistem mpn g3',
#  'peminjaman ruangan berkomputer tanggal 21 januari 2020',
#  'peminjaman ruangan berkomputer tanggal 21 januari 2020',
#  'penyampaian informasi pengembangan sistem informasi lembaga national single window lnsw tahun 2021',
#  'permohonan penarikan link dan pembukaan interkoneksi host to host pt indomarco pristama ke sistem mpn g3',
#  'peminjaman ruangan berkomputer tanggal 21 januari 2020',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyampaian initiative charter program rbtk 2020 2024',
#  'strategi percepatan pelaksanaan anggaran ta 2020',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyampaian initiative charter program rbtk 2020 2024',
#  'laporan hasil uji kerentanan vulnerability test aplikasi simfoni versi 4 p1',
#  'penyampaian initiative charter program rbtk 2020 2024',
#  'penyampaian tim teknis dja untuk kegiatan akhir tahun 2019',
#  'penyampaian initiative charter program rbtk 2020 2024',
#  'rancangan keputusan kepala pusintek tentang baseline konfigurasi keamanan perangkat teknologi informasi dan komunikasi kementerian keuangan area basis data',
#  'strategi percepatan pelaksanaan anggaran ta 2020',
#  'permohonan penarikan link dan pembukaan interkoneksi host to host pt indomarco pristama ke sistem mpn g3',
#  'rancangan keputusan kepala pusintek tentang baseline konfigurasi keamanan perangkat teknologi informasi dan komunikasi kementerian keuangan area basis data',
#  'strategi percepatan pelaksanaan anggaran ta 2020',
#  'rancangan keputusan kepala pusintek tentang baseline konfigurasi keamanan perangkat teknologi informasi dan komunikasi kementerian keuangan area basis data',
#  'strategi percepatan pelaksanaan anggaran ta 2020',
#  'laporan hasil uji kerentanan vulnerability test aplikasi bios g2 p5',
#  'penyampaian hasil rapat cab selasa',
#  'rencana pengelolaan kinerja pusintek triwulan iv tahun 2019',
#  'rencana pengadaan perangkat pengguna di lingkungan kementerian keuangan tahun anggaran 2021',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyampaian status tindak lanjut atas rekomendasi hasil audit tik inspektorat jenderal di lingkungan pusintek tahun 2019',
#  'usulan nama pejabat pegawai tim teknis sewa komunikasi data eksternal kemenkeu ta 2020',
#  'rencana pengelolaan kinerja pusintek triwulan iv tahun 2019',
#  'penyampaian status tindak lanjut atas rekomendasi hasil audit tik inspektorat jenderal di lingkungan pusintek tahun 2019',
#  'usulan nama pejabat pegawai tim teknis sewa komunikasi data eksternal kemenkeu ta 2020',
#  'penyampaian status tindak lanjut atas rekomendasi hasil audit tik inspektorat jenderal di lingkungan pusintek tahun 2019',
#  'laporan hasil uji kerentanan vulnerability test aplikasi simfoni versi 4 p1',
#  'rencana pengelolaan kinerja pusintek triwulan iv tahun 2019',
#  'penyampaian status tindak lanjut atas rekomendasi hasil audit tik inspektorat jenderal di lingkungan pusintek tahun 2019',
#  'laporan hasil uji kerentanan vulnerability test aplikasi simfoni versi 4 p1',
#  'pengembangan modul admin alpha terintegrasi hris',
#  'penyampaian status tindak lanjut atas rekomendasi hasil audit tik inspektorat jenderal di lingkungan pusintek tahun 2019',
#  'pengembangan modul admin alpha terintegrasi hris',
#  'pengembangan modul admin alpha terintegrasi hris',
#  'rencana pengelolaan kinerja pusintek triwulan iv tahun 2019',
#  'penyampaian laporan hasil inventarisasi pada pusintek',
#  'penyampaian status tindak lanjut atas rekomendasi hasil audit tik inspektorat jenderal di lingkungan pusintek tahun 2019',
#  'undangan fgd terkait pembahasan aplikasi e tco dalam rangka implementasi tco di lingkungan kementerian keuangan',
#  'penyampaian status tindak lanjut atas rekomendasi hasil audit tik inspektorat jenderal di lingkungan pusintek tahun 2019',
#  'penyampaian laporan simplifikasi pelayanan kementerian keuangan tahun 2019',
#  'surat perintah kerja lembur bidang manajemen layanan tik desember 2019',
#  'penyampaian laporan simplifikasi pelayanan kementerian keuangan tahun 2019',
#  'permintaan konsumsi',
#  'penyampaian laporan simplifikasi pelayanan kementerian keuangan tahun 2019',
#  'penyampaian status tindak lanjut atas rekomendasi hasil audit tik inspektorat jenderal di lingkungan pusintek tahun 2019',
#  'penyampaian status tindak lanjut atas rekomendasi hasil audit tik inspektorat jenderal di lingkungan pusintek tahun 2019',
#  'penyampaian laporan simplifikasi pelayanan kementerian keuangan tahun 2019',
#  'penyampaian status tindak lanjut atas rekomendasi hasil audit tik inspektorat jenderal di lingkungan pusintek tahun 2019',
#  'penyampaian surat keterangan tugas tambahan',
#  'laporan hasil uji beban performance test aplikasi sakti web djpb ke 3',
#  'persetujuan besaran uang persediaan up kartu kredit pemerintah',
#  'penyampaian surat keterangan tugas tambahan',
#  'laporan capaian kegiatan dukungan tik terhadap is rbtk 2019',
#  'laporan capaian kegiatan dukungan tik terhadap is rbtk 2019',
#  'penyampaian surat keterangan tugas tambahan',
#  'laporan hasil uji beban performance test aplikasi sakti web djpb ke 3',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyampaian notula rapat koordinasi pelaksanaan wbk wbbm tahun 2020',
#  'laporan hasil uji beban performance test aplikasi sakti web djpb ke 3',
#  'laporan capaian kegiatan dukungan tik terhadap is rbtk 2019',
#  'laporan hasil uji beban performance test aplikasi sakti web djpb ke 3',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyampaian surat keterangan tugas tambahan',
#  'penyelenggaraan rapat kerja raker rapat koordinasi rakor ',
#  'penyampaian surat keterangan tugas tambahan',
#  'laporan hasil uji beban performance test aplikasi sakti web djpb ke 3',
#  'penyampaian surat keterangan tugas tambahan',
#  'laporan capaian kegiatan dukungan tik terhadap is rbtk 2019',
#  's prin plh kabid kiktik cuti tahunan plh yang ditunjuk ismail fahmi',
#  'penyampaian surat keterangan tugas tambahan',
#  'permintaan usulan pagu indikatif ta 2021 lingkup eselon i sekretariat jenderal kemenkeu',
#  'surat perintah kerja lembur bidang pengembangan sistem informasi desember 2019',
#  'perubahan undangan dialog kinerja organisasi dko periode triwulan iv tahun 2019',
#  'surat perintah kerja lembur bidang pengembangan sistem informasi desember 2019',
#  's prin plh kabid kiktik cuti tahunan plh yang ditunjuk ismail fahmi',
#  'strategi percepatan pelaksanaan anggaran ta 2020',
#  'penyampaian laporan bulanan penerbitan spm periode desember 2019',
#  's prin plh kabid kiktik cuti tahunan plh yang ditunjuk ismail fahmi',
#  'laporan capaian kegiatan dukungan tik terhadap is rbtk 2019',
#  'penyampaian laporan pekerjaan bidang psi bulan juli 2019',
#  'permohonan kebutuhan penunjang workshop cluster database management',
#  'permohonan penandatanganan perubahan keputusan kpa',
#  'permohonan penambahan bandwidth',
#  'surat tugas perubahan shift agustus 2019',
#  'teliti dan pendapat permohonan penambahan bandwidth',
#  'sprin plh kepala bidang manajemen layanan data',
#  'sprin plh kepala bidang manajemen layanan data',
#  'sprin plh kepala bidang manajemen layanan data',
#  'sprin plh kepala bidang manajemen layanan data',
#  'sprin plh kepala bidang manajemen layanan data',
#  'permintaan tanggapan atas rancangan surat edaran tentang pencegahan dan penanganan ancaman malware khususnya ransomware jenis coharos',
#  'permintaan tanggapan atas rancangan surat edaran tentang pencegahan dan penanganan ancaman malware khususnya ransomware jenis coharos',
#  'permintaan tanggapan atas rancangan surat edaran tentang pencegahan dan penanganan ancaman malware khususnya ransomware jenis coharos',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'penyampaian template kajian di lingkungan pusintek',
#  'penyampaian template kajian di lingkungan pusintek',
#  'penyampaian template kajian di lingkungan pusintek',
#  'penyampaian template kajian di lingkungan pusintek',
#  'penyampaian template kajian di lingkungan pusintek',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'laporan monitoring kegiatan pengadaan di lingkungan pusintek bulan juli tahun anggaran ta 2019',
#  'laporan monitoring kegiatan pengadaan di lingkungan pusintek bulan juli tahun anggaran ta 2019',
#  'laporan monitoring kegiatan pengadaan di lingkungan pusintek bulan juli tahun anggaran ta 2019',
#  'laporan monitoring kegiatan pengadaan di lingkungan pusintek bulan juli tahun anggaran ta 2019',
#  'laporan monitoring kegiatan pengadaan di lingkungan pusintek bulan juli tahun anggaran ta 2019',
#  'internalisasi penerapan zona integritas menuju wilayah bebas dari korupsi',
#  'kick off meeting pengadaan perangkat keamanan informasi ta 2019',
#  'tindak lanjut rencana serah terima barang milik negara pusintek ke djbc',
#  'tindak lanjut rencana serah terima barang milik negara pusintek ke djbc',
#  'tindak lanjut rencana serah terima barang milik negara pusintek ke djbc',
#  'kegiatan perlombaan dalam rangka hut ri ke 74 di lingkungan pusintek',
#  'upacara bendera peringatan hari ulang tahun ke 74 kemerdekaan republik indonesia tahun 2019 tanggal 17 agustus 2019',
#  'permintaan jaringan wifi',
#  'sprin plh kepala bidang manajemen layanan data',
#  'surat perintah kerja lembur bidang manajemen layanan tik juli 2019',
#  'surat perintah kerja lembur bidang manajemen layanan tik juli 2019',
#  'surat perintah kerja lembur bidang manajemen layanan tik juli 2019',
#  'surat perintah kerja lembur bidang manajemen layanan tik juli 2019',
#  'surat perintah kerja lembur bidang manajemen layanan tik juli 2019',
#  'permohonan penyediaan server development untuk aplikasi knl',
#  'permohonan penyediaan server development untuk aplikasi knl',
#  'surat tugas perubahan shift agustus 2019',
#  'surat tugas perubahan shift agustus 2019',
#  'surat tugas perubahan shift agustus 2019',
#  'surat tugas perubahan shift agustus 2019',
#  'penyampaian intra info transformasi edisi vii tahun 2019',
#  'surat keputusan tentang informasi jabatan bagi jabatan struktural di lingkungan kptikbmn',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'pelaksanaan ujian ulangan tahap ii tahun 2019',
#  'penyampaian hasil rapat cab selasa',
#  'laporan hasil uji beban performance test aplikasi portal sso mpn g3',
#  'laporan hasil uji beban performance test aplikasi portal sso mpn g3',
#  'laporan hasil uji beban performance test aplikasi portal sso mpn g3',
#  'laporan hasil uji beban performance test aplikasi portal sso mpn g3',
#  'laporan hasil uji beban performance test aplikasi portal sso mpn g3',
#  'sprin plh kepala bidang manajemen layanan data',
#  'laporan monitoring kegiatan pengadaan di lingkungan pusintek bulan juli tahun anggaran ta 2019',
#  'permintaan tanggapan atas rancangan surat edaran tentang pencegahan dan penanganan ancaman malware khususnya ransomware jenis coharos',
#  'tindak lanjut rencana serah terima barang milik negara pusintek ke djbc',
#  'penyampaian hasil rapat cab selasa',
#  'permintaan tanggapan atas rancangan surat edaran tentang pencegahan dan penanganan ancaman malware khususnya ransomware jenis coharos',
#  'penyampaian notula rapat pembahasan implementasi dan evaluasi pengembangan sakti',
#  'penyampaian notula rapat pembahasan implementasi dan evaluasi pengembangan sakti',
#  'penyampaian notula rapat pembahasan implementasi dan evaluasi pengembangan sakti',
#  'penyampaian notula rapat pembahasan implementasi dan evaluasi pengembangan sakti',
#  'penyampaian notula rapat pembahasan implementasi dan evaluasi pengembangan sakti',
#  'penyampaian template kajian di lingkungan pusintek',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian template kajian di lingkungan pusintek',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab selasa',
#  'internalisasi penerapan zona integritas menuju wilayah bebas dari korupsi',
#  'bimbingan teknis penyusunan rencana kebutuhan barang milik negara rkbmn tahun 2021',
#  'penyampaian salinan surat edaran menteri keuangan tentang pelaksanaan pemeliharaan data sumber daya manusia pada human resources information system bagi seluruh pegawai di lingkungan kementerian keuangan',
#  'penyampaian salinan surat edaran menteri keuangan tentang pelaksanaan pemeliharaan data sumber daya manusia pada human resources information system bagi seluruh pegawai di lingkungan kementerian keuangan',
#  'persiapan penilaian kantor berpredikat zona integritas wilayah bebas korupsi zi wbk ',
#  'sprin plh kepala bidang manajemen layanan data',
#  'persiapan penilaian kantor berpredikat zona integritas wilayah bebas korupsi zi wbk ',
#  'program pendidikan kementerian keuangan mengajar',
#  'permintaan usulan nama kepala perwakilan',
#  'undangan simposium bantuan hukum',
#  'rekomendasi terkait perpajakan pada kawasan berikat',
#  'permohonan perubahan jadwal shift bidang operasional tik',
#  'surat tugas pelatihan terkait kontrak pengadaan upgrade perangkat database server',
#  'penyampaian lembur petugas kebersihan bulan juli 2019',
#  'penyampaian lembur pramubakti bulan juli 2019',
#  'tindak lanjut rencana serah terima barang milik negara pusintek ke djbc',
#  'penyampaian template kajian di lingkungan pusintek',
#  'sprin plh kepala bidang manajemen layanan data',
#  'teliti dan pendapat atas undangan workshop program interkoneksi sistem skk migas dengan stakeholder tahun 2019',
#  'undangan workshop program interkoneksi sistem skk migas dengan stakeholder tahun 2019',
#  'laporan monitoring kegiatan pengadaan di lingkungan pusintek bulan juli tahun anggaran ta 2019',
#  'laporan monitoring kegiatan pengadaan di lingkungan pusintek bulan juli tahun anggaran ta 2019',
#  'laporan monitoring kegiatan pengadaan di lingkungan pusintek bulan juli tahun anggaran ta 2019',
#  'laporan monitoring kegiatan pengadaan di lingkungan pusintek bulan juli tahun anggaran ta 2019',
#  'pelaksanaan survei integritas organisasi dan jabatan dalam rangka evaluasi pelaksanaan reformasi birokrasi tahun 2019',
#  'permintaan tanggapan atas rancangan surat edaran tentang pencegahan dan penanganan ancaman malware khususnya ransomware jenis coharos',
#  'permintaan tanggapan atas rancangan surat edaran tentang pencegahan dan penanganan ancaman malware khususnya ransomware jenis coharos',
#  'permintaan tanggapan atas rancangan surat edaran tentang pencegahan dan penanganan ancaman malware khususnya ransomware jenis coharos',
#  'permintaan tanggapan atas rancangan surat edaran tentang pencegahan dan penanganan ancaman malware khususnya ransomware jenis coharos',
#  'permintaan tanggapan atas rancangan surat edaran tentang pencegahan dan penanganan ancaman malware khususnya ransomware jenis coharos',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'penyampaian template kajian di lingkungan pusintek',
#  'penyampaian template kajian di lingkungan pusintek',
#  'penyampaian template kajian di lingkungan pusintek',
#  'penyampaian template kajian di lingkungan pusintek',
#  'surat tugas perubahan shift agustus 2019',
#  'surat tugas perubahan shift agustus 2019',
#  'surat tugas perubahan shift agustus 2019',
#  'surat tugas perubahan shift agustus 2019',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'sprin plh kepala subbidang operasional pusat data',
#  'sprin plh kepala subbidang operasional pusat data',
#  'sprin plh kepala subbidang operasional pusat data',
#  'sprin plh kepala subbidang operasional pusat data',
#  'sprin plh kepala subbidang dukungan teknis tingkat ii',
#  'sprin plh kepala subbidang dukungan teknis tingkat ii',
#  'sprin plh kepala subbidang dukungan teknis tingkat ii',
#  'sprin plh kepala subbidang dukungan teknis tingkat ii',
#  'penyampaian template kajian di lingkungan pusintek',
#  'penyampaian template kajian di lingkungan pusintek',
#  'penyampaian template kajian di lingkungan pusintek',
#  'penyampaian template kajian di lingkungan pusintek',
#  'undangan simposium bantuan hukum',
#  'permintaan usulan nama kepala perwakilan',
#  'laporan hasil uji kerentanan vulnerability test crm lpdp p1',
#  'laporan hasil uji kerentanan vulnerability test crm lpdp p1',
#  'laporan hasil uji kerentanan vulnerability test crm lpdp p1',
#  'laporan hasil uji kerentanan vulnerability test aplikasi hris api profile p1',
#  'laporan hasil uji kerentanan vulnerability test hris api diklat p1',
#  'penyampaian laporan ketertiban pegawai periode 16 juli s d 12 agustus 2019',
#  'penyampaian laporan ketertiban pegawai periode 16 juli s d 12 agustus 2019',
#  'laporan hasil uji kerentanan vulnerability test portal rekon mpn g3 p3',
#  'permintaan konsumsi kegiatan rapat pembahasan pekerjaan sewa komunikasi data internet link 2 kemenkeu ta 2019',
#  'permohonan perubahan jadwal shift bidang operasional tik',
#  'sprin plh kepala bidang manajemen layanan data',
#  'tindak lanjut rencana serah terima barang milik negara pusintek ke djbc',
#  'tindak lanjut rencana serah terima barang milik negara pusintek ke djbc',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab selasa',
#  'penyampaian hasil rapat cab kamis',
#  'penyampaian hasil rapat cab kamis',
#  'penyampaian hasil rapat cab kamis',
#  'teliti pendapat atas permohonan bantuan pemasangan vpn virtual private network pada gedung danahutama lman',
#  'penyampaian konsep keputusan kepala pusintek tentang pembentukan tim sensus barang milik negara di lingkungan pusintek sekretariat jenderal kementerian keuangan tahun anggaran 2019',
#  'penyampaian konsep keputusan kepala pusintek tentang pembentukan tim sensus barang milik negara di lingkungan pusintek sekretariat jenderal kementerian keuangan tahun anggaran 2019',
#  'penyampaian konsep keputusan kepala pusintek tentang pembentukan tim sensus barang milik negara di lingkungan pusintek sekretariat jenderal kementerian keuangan tahun anggaran 2019',
#  'penyampaian konsep keputusan kepala pusintek tentang pembentukan tim sensus barang milik negara di lingkungan pusintek sekretariat jenderal kementerian keuangan tahun anggaran 2019',
#  'penyampaian surat edaran menteri keuangan tentang pelaksanaan pemeliharaan data sumber daya manusia pada hris bagi seluruh pegawai di lingkungan kementerian keuangan',
#  'penyampaian surat edaran menteri keuangan tentang pelaksanaan pemeliharaan data sumber daya manusia pada hris bagi seluruh pegawai di lingkungan kementerian keuangan',
#  'penyampaian surat edaran menteri keuangan tentang pelaksanaan pemeliharaan data sumber daya manusia pada hris bagi seluruh pegawai di lingkungan kementerian keuangan',
#  'permohonan penerbitan surat tugas workshop internal audit',
#  'penyampaian konsep keputusan kepala pusintek tentang pembentukan tim kerja kegiatan hut ri ke 74 di lingkungan pusintek',
#  'permohonan peningkatan bandwidth pada kppn saumlaki',
#  'persiapan penilaian kantor berpredikat zona integritas wilayah bebas korupsi zi wbk ',
#  'sprin plh kepala bidang manajemen layanan data',
#  'teliti dan pendapat atas permohonan penambahan bandwidth spmb pkn stan tahap kedua',
#  'penyampaian template kajian di lingkungan pusintek',
#  'laporan hasil uji kerentanan vulnerability test modul knd p1',
#  'teliti dan pendapat permohonan penambahan bandwidth',
#  'teliti dan pendapat permohonan penambahan bandwidth',
#  'permohonan persetujuan pembentukan tim auditor internal integrated management system ims di lingkungan pusintek tahun 2019',
#  'permohonan persetujuan pembentukan tim auditor internal integrated management system ims di lingkungan pusintek tahun 2019',
#  'tindak lanjut rencana serah terima barang milik negara pusintek ke djbc',
#  'tindak lanjut rencana serah terima barang milik negara pusintek ke djbc',
#  'kick off meeting pengadaan perangkat keamanan informasi ta 2019',
#  'kick off meeting pengadaan perangkat keamanan informasi ta 2019',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'surat tugas perubahan shift agustus 2019',
#  'surat tugas perubahan shift agustus 2019',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'permintaan akp jabatan dan individu tahun 2020 di lingkungan pusintek',
#  'persiapan penilaian kantor berpredikat zona integritas wilayah bebas korupsi zi wbk ',
#  'laporan hasil uji beban performance test aplikasi portal sso mpn g3',
#  'laporan hasil uji beban performance test aplikasi portal sso mpn g3',
#  'surat perintah kerja lembur bidang keamanan informasi dan kelangsungan tik juli 2019',
#  'surat perintah kerja lembur bidang keamanan informasi dan kelangsungan tik juli 2019',
#  'permintaaan konsumsi pelaksanaan uji fungsionalitas dc drc unit direktorat jenderal kekayaan negara djkn ',
#  'permohonan kebutuhan penunjang transfer knowledge pengembangan infrastruktur perimbangan keuangan kementerian keuangan kemenkeu ta 2019',
#  'permintaan konsumsi rapat koordinasi tim organisasi keamanan informasi kementerian keuangan',
#  'penyampaian progress capaian kinerja sampai dengan juli 2019',
#  'penyampaian progress capaian kinerja sampai dengan juli 2019',
#  'permohonan penyediaan server development untuk aplikasi knl',
#  'permohonan penyediaan server development untuk aplikasi knl',
#  'permohonan penyediaan server development untuk aplikasi knl',
#  'permohonan penyediaan server development untuk aplikasi knl',
#  'permohonan persetujuan pelaksanaan workshop internal auditor',
#  'permohonan persetujuan pelaksanaan workshop internal auditor',
#  'surat perintah kerja lembur bidang operasional tik juli 2019',
#  'surat perintah kerja lembur bidang operasional tik juli 2019',
#  'surat perintah kerja lembur bidang operasional tik juli 2019',
#  'surat perintah kerja lembur bidang operasional tik juli 2019',
#  'penunjukan pengangkatan kepala sekretariat perwakilan kementerian keuangan provinsi sulawesi barat',
#  'sprin plh kepala subbidang dukungan teknis tingkat ii',
#  'sprin plh kepala subbidang dukungan teknis tingkat ii',
#  'sprin plh kepala subbidang dukungan teknis tingkat ii',
#  'sprin plh kepala subbidang dukungan teknis tingkat ii',
#  'sprin plh kepala subbidang operasional pusat data',
#  'sprin plh kepala subbidang operasional pusat data',
#  'sprin plh kepala subbidang operasional pusat data',
#  'sprin plh kepala subbidang operasional pusat data',
#  'surat tugas perubahan shift agustus 2019',
#  'surat tugas perubahan shift agustus 2019',
#  'surat tugas perubahan shift agustus 2019',
#  'surat tugas perubahan shift agustus 2019',
#  'informasi perubahan pindah alamat kpknl samarinda dan kanwil djkn kalimantan timur dan utara',
#  'informasi perubahan pindah alamat kpknl samarinda dan kanwil djkn kalimantan timur dan utara',
#  'informasi perubahan pindah alamat kpknl samarinda dan kanwil djkn kalimantan timur dan utara',
#  'permohonan peningkatan kapasitas bandwidth intranet sementara link kementerian perhubungan',
#  'penyampaian revisi hasil reviu usulan uraian jabatan berdasarkan tugas dan fungsi di lingkungan kantor pengelolaan tik dan bmn',
#  'user acceptance test uat portal penerimaan modul penerimaan negara generasi ke 3 mpn g3 dan laku pandai pada djp',
#  'peranan kptikbmn semarang terkait dengan rencana integrasi jaringan ditjen pajak dengan jaringan kemenkeu',
#  'penyampaian laporan progress planning support konsolidasi anggaran network pajak',
#  'peran kppd dalam planning support konsolidasi anggaran network djp',
#  'permohonan peningkatan bandwidth pada kppn saumlaki',
#  'permohonan peningkatan bandwidth pada kppn saumlaki',
#  'request for a meeting between pusintek and huawei management team',
#  'request for a meeting between pusintek and huawei management team',
#  'penawaran kegiatan transfer knowledge pengembangan infrastruktur perimbangan keuangan kementerian keuangan kemenkeu ta 2019',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'katertiban dan keamanan di kantor pusat kementerian keuangan',
#  'st shift kppd periode agustus 2019',
#  'surat tugas pendampingan implementasi nadine unit es 2 setjen',
#  ' disposisi sekretaris jenderal laporan proyek tik strategis kemenkeu triwulan ii tahun 2019',
#  ' disposisi sekretaris jenderal laporan proyek tik strategis kemenkeu triwulan ii tahun 2019',
#  'penyampaian tindak lanjut rekomendasi hasil complience audit inspektorat jenderal pada kptikbmn makassar tahun 2018',
#  'penyampaian petikan dan salinan keputusan menteri keuangan nomor 395 km 1 up 11 2019 tanggal 25 juli 2019',
#  'laporan hasil uji beban performance test aplikasi microweb ditjen perbendaharaan',
#  'laporan hasil uji beban performance test aplikasi microweb ditjen perbendaharaan',
#  'laporan hasil uji beban performance test aplikasi microweb ditjen perbendaharaan',
#  'laporan hasil uji beban performance test aplikasi pindah lokasi ujian stan',
#  'laporan hasil uji beban performance test aplikasi pindah lokasi ujian stan',
#  'laporan hasil uji beban performance test aplikasi pindah lokasi ujian stan',
#  'permohonan izin audit internal implementasi integrated management system area drc kementerian keuangan tahun 2019',
#  'permohonan analisa tingkat kerusakan gedung dan perincian anggaran biaya rehab rumah susun kementerian keuangan di denpasar',
#  'permohonan analisa tingkat kerusakan gedung dan perincian anggaran biaya rehab rumah susun kementerian keuangan di denpasar',
#  'permintaan akun individu',
#  'permintaan akun individu',
#  'permintaan akun individu',
#  'permintaan akun individu',
#  'undangan rdk evaluasi temuan uji kelayakan aplikasi e jafung',
#  'tindak lanjut hasil one on one meeting terkait penajaman anggaran kementerian keuangn ta 2019 dan ta 2020',
#  'tindak lanjut hasil one on one meeting terkait penajaman anggaran kementerian keuangn ta 2019 dan ta 2020',
#  'hasil knowledge sharing mengenai peran transformasi digital dalam membentuk pemerintahan yang efektif dan akuntabel',
#  'hasil knowledge sharing mengenai peran transformasi digital dalam membentuk pemerintahan yang efektif dan akuntabel',
#  'hasil knowledge sharing mengenai peran transformasi digital dalam membentuk pemerintahan yang efektif dan akuntabel',
#  'surat tugas konsinyering pengembangan dan pengujian menu aplikasi om span',
#  ' disposisi sekretaris jenderal penyampaian notula rapat koordinasi tim organisasi keamanan informasi unit di lingkungan sekretariat jenderal',
#  ' disposisi sekretaris jenderal penyampaian notula rapat koordinasi tim organisasi keamanan informasi unit di lingkungan sekretariat jenderal',
#  ' disposisi sekretaris jenderal penyampaian notula rapat koordinasi tim organisasi keamanan informasi unit di lingkungan sekretariat jenderal',
#  'permohonan magang an hanif raihan oktaviano',
#  'penyampaian daftar pegawai yang merayakan ulang tahun di lingkungan sekretariat jenderal bulan agustus tahun 2019',
#  'permohonan tanggapan persetujuan terhadap rancangan keputusan menteri keuangan tentang infrastruktur tik di lingkungan kementerian keuangan',
#  'permohonan izin perjalanan dinas luar ke disaster recovery center drc kementerian keuangan di balikpapan',
#  'permintaan rekomendasi pegawai berprestasi bagi pegawai negeri sipil di lingkungan pusintek',
#  'permintaan rekomendasi pegawai berprestasi bagi pegawai negeri sipil di lingkungan pusintek',
#  'monitoring implementasi mpn g3',
#  'surat tugas rdk finalisasi rencana pelaksanaan drp drill sistem span 2019',
#  'pemberitahuan rencana downtime',
#  'permohonan izin perjalanan dinas luar ke disaster recovery center drc kementerian keuangan di balikpapan',
#  'surat tugas pendampingan implementasi nadine unit es 2 setjen',
#  'surat tugas pendampingan implementasi nadine unit es 2 setjen',
#  'permintaan perubahan ruang lingkup layanan sewa komunikasi data kementerian keuangan tahun anggaran 2019',
#  'penyampaian laporan ringkasan rapat evaluasi implementasi mpn g3',
#  'penyampaian laporan ringkasan rapat evaluasi implementasi mpn g3',
#  'penyampaian laporan ringkasan rapat evaluasi implementasi mpn g3',
#  'penyampaian laporan ringkasan rapat evaluasi implementasi mpn g3',
#  'penyampaian laporan ringkasan rapat evaluasi implementasi mpn g3',
#  'penyampaian laporan ringkasan rapat evaluasi implementasi mpn g3',
#  'laporan hasil uji kerentanan vulnerability test aplikasi formulir permintaan pindah lokasi ujian p1',
#  'laporan hasil uji kerentanan vulnerability test aplikasi formulir permintaan pindah lokasi ujian p1',
#  'implementasi drp disaster recovery plan drill sistem perbendaharaan dan anggaran negara span tahun 2019',
#  'penyampaian dokumen kelengkapan permintaan pembukaan routing interkoneksi jaringan untuk mitra distribusi philip sekuritas indonesia dan investee',
#  'penyampaian dokumen kelengkapan permintaan pembukaan routing interkoneksi jaringan untuk mitra distribusi philip sekuritas indonesia dan investee',
#  'rencana pelaksanaan drp drill sistem span 2019',
#  'rencana pelaksanaan drp drill sistem span 2019',
#  'rencana pelaksanaan drp drill sistem span 2019',
#  ' disposisi sekretaris jenderal laporan proyek tik strategis kemenkeu triwulan ii tahun 2019',
#  ' disposisi sekretaris jenderal laporan proyek tik strategis kemenkeu triwulan ii tahun 2019',
#  ' disposisi sekretaris jenderal laporan proyek tik strategis kemenkeu triwulan ii tahun 2019',
#  ' disposisi sekretaris jenderal tindak lanjut permohonan penggunaan domain dan hosting pknstan ac id',
#  ' disposisi sekretaris jenderal tindak lanjut permohonan penggunaan domain dan hosting pknstan ac id',
#  ' disposisi sekretaris jenderal tindak lanjut permohonan penggunaan domain dan hosting pknstan ac id',
#  'pemberitahuan rencana downtime',
#  'pemberitahuan rencana downtime',
#  'pemberitahuan rencana downtime',
#  'penunjukan pelaksana harian plh kepala pusintek',
#  'penunjukan pelaksana harian plh kepala pusintek',
#  'penunjukan pelaksana harian plh kepala pusintek',
#  ' disposisi sekretaris jenderal hasil rapat pembahasan terkait pemanfaatan solar dex data center pusintek oleh pangkalan sarana operasi bea dan cukai tanjung priok',
#  ' disposisi sekretaris jenderal hasil rapat pembahasan terkait pemanfaatan solar dex data center pusintek oleh pangkalan sarana operasi bea dan cukai tanjung priok',
#  ' disposisi sekretaris jenderal hasil rapat pembahasan terkait pemanfaatan solar dex data center pusintek oleh pangkalan sarana operasi bea dan cukai tanjung priok',
#  'permohonan penambahan bandwidth di treasury learning center tlc ',
#  'permohonan penambahan bandwidth di treasury learning center tlc ',
#  'laporan hasil uji kerentanan vulnerability test aplikasi formulir permintaan pindah lokasi ujian p1',
#  'laporan hasil uji kerentanan vulnerability test aplikasi formulir permintaan pindah lokasi ujian p1',
#  's prin plh kepala kptik bmn surabaya dukpim kunjungan kerja komisi xi dpr ri',
#  'permintaan perubahan ruang lingkup layanan sewa komunikasi data intranet kementerian keuangan ta 2019',
#  'surat pernyataan peningkatan keamanan server dan jaringan sistem mpn dan sikp',
#  'laporan pendampingan kegiatan roll out i dan ii modul penerimaan negara generasi ketiga mpn g3 ',
#  'laporan pendampingan kegiatan roll out i dan ii modul penerimaan negara generasi ketiga mpn g3 ',
#  'laporan pendampingan kegiatan roll out i dan ii modul penerimaan negara generasi ketiga mpn g3 ',
#  'laporan pendampingan kegiatan roll out i dan ii modul penerimaan negara generasi ketiga mpn g3 ',
#  'laporan pendampingan kegiatan roll out i dan ii modul penerimaan negara generasi ketiga mpn g3 ',
#  'laporan pendampingan kegiatan roll out i dan ii modul penerimaan negara generasi ketiga mpn g3 ',
#  'permohonan interkoneksi host to host bank kalsel unit usaha syariah ke sikp',
#  'penyampaian progres pelaksanaan survei kepuasan pengguna layanan skpl sekretariat jenderal',
#  'permohonan pembukaan routing dan pendaftaran dns badan siber dan sandi negara bssn di dns kementerian keuangan',
#  'penyampaian rekapitulasi spm periode bulan juli 2019',
#  'penyampaian rekapitulasi spm periode bulan juli 2019',
#  ' disposisi sekretaris jenderal tindak lanjut permohonan penggunaan domain dan hosting pknstan ac id',
#  ' disposisi sekretaris jenderal tindak lanjut permohonan penggunaan domain dan hosting pknstan ac id',
#  ' disposisi sekretaris jenderal tindak lanjut permohonan penggunaan domain dan hosting pknstan ac id',
#  'pemberitahuan rencana downtime',
#  'permintaan daftar arsip aktif',
#  'permintaan daftar arsip aktif',
#  'tindak lanjut hasil one on one meeting terkait penajaman anggaran kementerian keuangan ta 2019 dan ta 2020',
#  'tindak lanjut hasil one on one meeting terkait penajaman anggaran kementerian keuangan ta 2019 dan ta 2020',
#  'tindak lanjut hasil one on one meeting terkait penajaman anggaran kementerian keuangan ta 2019 dan ta 2020',
#  ' disposisi sekretaris jenderal laporan proyek tik strategis kemenkeu triwulan ii tahun 2019',
#  ' disposisi sekretaris jenderal laporan proyek tik strategis kemenkeu triwulan ii tahun 2019',
#  ' disposisi sekretaris jenderal laporan proyek tik strategis kemenkeu triwulan ii tahun 2019',
#  'permintaan penyampaian laporan capaian kinerja kemenkeu two dan kemenkeu three periode bulan juli 2019',
#  'laporan monitoring pending matters pada dams pusintek cut off 22 juli 2019',
#  'hasil rapat tindak lanjut pengembangan teknologi informasi kehumasan house of trust',
#  'hasil knowledge sharing mengenai peran transformasi digital dalam membentuk pemerintahan yang efektif dan akuntabel',
#  'permintaan rekomendasi pegawai berprestasi bagi pegawai negeri sipil di lingkungan pusintek',
#  'surat tugas narasumber security awareness di lingkungan pppk',
#  ' disposisi sekretaris jenderal laporan proyek tik strategis kemenkeu triwulan ii tahun 2019',
#  ' disposisi sekretaris jenderal laporan proyek tik strategis kemenkeu triwulan ii tahun 2019',
#  ' disposisi sekretaris jenderal laporan proyek tik strategis kemenkeu triwulan ii tahun 2019',
#  ' disposisi sekretaris jenderal laporan proyek tik strategis kemenkeu triwulan ii tahun 2019',
#  ' disposisi sekretaris jenderal laporan proyek tik strategis kemenkeu triwulan ii tahun 2019',
#  'penyampaian laporan pelaksanaan dko dan matriks tindak lanjut dko serta notula rapat dko triwulan ii tahun 2019',
#  'laporan pembahasan rpp penyelenggaraan sistem dan transaksi elektronik',
#  ' disposisi sekretaris jenderal tindak lanjut permohonan penggunaan domain dan hosting pknstan ac id',
#  ' disposisi sekretaris jenderal tindak lanjut permohonan penggunaan domain dan hosting pknstan ac id',
#  'permintaan akun individu',
#  'permintaan penyampaian laporan capaian kinerja kemenkeu two dan kemenkeu three periode bulan juli 2019',
#  'permohonan peminjaman aula',
#  'undangan kegiatan beauty workshop',
#  'undangan kegiatan beauty workshop',
#  'permohonan bantuan pelaksanaan sholat idhul adha dan pemotongan hewan qurban 1440 h',
#  'permohonan bantuan pelaksanaan sholat idhul adha dan pemotongan hewan qurban 1440 h',
#  'undangan sharing session gerakan sadar kualitas kontrak kinerja ',
#  'tindak lanjut hasil one on one meeting terkait penajaman anggaran kementerian keuangan ta 2019 dan ta 2020',
#  'permohonan penarikan link baru sikp itc finance',
#  'undangan kegiatan beauty workshop',
# ...
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'penyampaian laporan evaluasi atas uji coba implementasi aplikasi nadine 2 0 di direktorat tpb dan direktorat kitsda',
#  'usulan pengalihan status barang sitaan komisi pemberantasan korupsi menjadi barang milik negara di lingkungan kptik bmn surabaya',
#  'usulan pengalihan status barang sitaan komisi pemberantasan korupsi menjadi barang milik negara di lingkungan kptik bmn surabaya',
#  'laporan hasil uji beban performance test aplikasi e sewa bmn p1',
#  'permohonan akses nadine',
#  'laporan hasil uji beban performance test aplikasi e sewa bmn p1',
#  'laporan hasil uji beban performance test aplikasi e sewa bmn p1',
#  'laporan hasil uji kerentanan vulnerability test aplikasi pnbp lelang p1',
#  'laporan hasil uji kerentanan vulnerability test aplikasi pnbp lelang p1',
#  'permintaan konsumsi',
#  'pemberitahuan pejabat pembuat komitmen',
#  'permintaan konsumsi kegiatan orientasi bagi pegawai baru sekretariat jenderal tahun 2019',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'penyampaian tindak lanjut arahan rapat pimpinan tik kementerian keuangan terkait aplikasi co location di unit eselon i',
#  'pembahasan aplikasi siman dan dashboard bmn',
#  'teliti dan pendapat permohonan pemaparan it infrastructure security solution',
#  'teliti dan pendapat permohonan pemaparan it infrastructure security solution',
#  'teliti dan pendapat permohonan pemaparan it infrastructure security solution',
#  'teliti dan pendapat permohonan pemaparan it infrastructure security solution',
#  'teliti dan pendapat permohonan pemaparan it infrastructure security solution',
#  'peminjaman perangkat berupa lcd led dan laptop',
#  'peminjaman perangkat berupa lcd led dan laptop',
#  'himbauan terkait penggunaan pakaian kerja pegawai',
#  'himbauan terkait penggunaan pakaian kerja pegawai',
#  'himbauan terkait penggunaan pakaian kerja pegawai',
#  'persetujuan besaran uang persediaan up kartu kredit pemerintah',
#  'laporan hasil pemantauan pengendalian utama ppu pada kantor pengelolaan teknologi informasi dan komunikasi dan barang milik negara kptik bmn denpasar tahun 2019',
#  'permintaan updating master aset objek asuransi barang milik negara',
#  'penyampaian rekapitulasi laporan utilitas intranet bulan mei s d juni 2019',
#  'penyampaian rekapitulasi laporan utilitas intranet bulan mei s d juni 2019',
#  'teliti pendapat permohonan penyediaan server training aplikasi bios g2',
#  'hasil rapat pembahasan terkait pemanfaatan solar dex data center pusintek oleh pangkalan sarana operasi bea dan cukai tanjung priok',
#  'hasil rapat pembahasan terkait pemanfaatan solar dex data center pusintek oleh pangkalan sarana operasi bea dan cukai tanjung priok',
#  'hasil rapat pembahasan terkait pemanfaatan solar dex data center pusintek oleh pangkalan sarana operasi bea dan cukai tanjung priok',
#  'hasil rapat pembahasan terkait pemanfaatan solar dex data center pusintek oleh pangkalan sarana operasi bea dan cukai tanjung priok',
#  'hasil rapat pembahasan terkait pemanfaatan solar dex data center pusintek oleh pangkalan sarana operasi bea dan cukai tanjung priok',
#  'hasil rapat pembahasan terkait pemanfaatan solar dex data center pusintek oleh pangkalan sarana operasi bea dan cukai tanjung priok',
#  'usulan pemeliharaan sarana dan prasarana gkn makassar',
#  'permintaan pengisian kuesioner business continuity awareness',
#  'laporan threat monitoring periode juni 2019',
#  'penunjukan pelaksana tugas plt kepala bidang pengembangan sistem informasi',
#  'penunjukan pelaksana tugas plt kepala bidang pengembangan sistem informasi',
#  'permintaan droping tunjangan kinerja dan tunjangan tambahan bulan agustus tahun 2019 pada kptik bmn surabaya',
#  'permintaan droping tunjangan kinerja bulan agustus tahun 2019 kantor pengelolaan tik dan bmn makassar',
#  'penunjukan pelaksana tugas plt kepala bidang pengembangan sistem informasi',
#  'penunjukan pelaksana tugas plt kepala bidang pengembangan sistem informasi',
#  'penunjukan pelaksana tugas plt kepala bidang pengembangan sistem informasi',
#  'penunjukan pelaksana tugas plt kepala bidang pengembangan sistem informasi',
#  'laporan monitoring kegiatan pengadaan di lingkungan pusintek bulan juni tahun anggaran ta 2019',
#  'laporan monitoring kegiatan pengadaan di lingkungan pusintek bulan juni tahun anggaran ta 2019',
#  'laporan monitoring kegiatan pengadaan di lingkungan pusintek bulan juni tahun anggaran ta 2019',
#  'laporan kegiatan pengelolaan tik dan bmn periode 24 juni 7 juli 2019',
#  'penyampaian laporan kegiatan kp tik dan bmn denpasar bulan mei tahun 2019',
#  'surat tugas sosialisasi security awareness tahun 2019',
#  'penyampaian data downtime sistem tik djkn bulan juni 2019',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'tindak lanjut permintaan perpanjangan cloud server development lembaga manajemen aset negara',
#  'tindak lanjut permintaan perpanjangan cloud server development lembaga manajemen aset negara',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian hasil rapat cab senin',
#  'penyampaian tanggapan atas dokumen kajian dan usulan kak pengadaan lisensi otomasi perkantoran kemenkeu ta 2019',
#  'tanggapan penyampaian kajian dan usulan kerangka acuan kerja kak pengadaan lisensi otomasi perkantoran kemenkeu ta 2019',
#  'surat tugas peserta capacity building pusintek 2019 pusat ',
#  'tanggapan penyampaian kajian dan usulan kerangka acuan kerja kak pengadaan lisensi otomasi perkantoran kemenkeu ta 2019',
#  'permohonan instalasi dan aktivasi microsoft office',
#  'penyampaian laporan permintaan dan pemenuhan perangkat lunak berlisensi periode bulan juni 2019',
#  'penyampaian update pengelolaan lisensi perangkat lunak',
#  'penyampaian progress registrasi sertifikat elektronik digital signature pada unit piloting aplikasi e office aplikasi nadine ',
#  'perubahan surat tugas tim teknis spmb pkn stan',
#  'penyampaian kajian dan usulan kerangka acuan kerja kak pengadaan lisensi otomasi perkantoran kemenkeu ta 2019',
#  'perubahan surat tugas peserta capacity building an faris nafi ul amal',
#  'hasil rapat tindak lanjut pengembangan teknologi informasi kehumasan house of trust',
#  'hasil rapat tindak lanjut pengembangan teknologi informasi kehumasan house of trust',
#  'hasil rapat tindak lanjut pengembangan teknologi informasi kehumasan house of trust',
#  'hasil rapat tindak lanjut pengembangan teknologi informasi kehumasan house of trust',
#  'laporan hasil rapat koordinasi tentang revisi terhadap peraturan menteri lembaga sebagai tindak lanjut arahan presiden terkait norma',
#  'laporan hasil pembahasan rpp tentang penyelenggaraan sistem dan transaksi elektronik pste ',
#  'permintaan daftar arsip aktif',
#  'laporan monitoring pending matters pada dams pusintek cut off 22 juli 2019',
#  'laporan monitoring pending matters pada dams pusintek cut off 22 juli 2019',
#  'penyampaian laporan pemantauan penerapan dan peningkatan smki periode triwulan ii',
#  'penyampaian laporan pemantauan penerapan dan peningkatan smki periode triwulan ii',
#  'penyampaian laporan pemantauan penerapan dan peningkatan smki periode triwulan ii',
#  'penyampaian laporan pemantauan penerapan dan peningkatan smki periode triwulan ii',
#  'penyampaian usulan implementasi baseline konfigurasi keamanan perangkat tik sebelum proses hosting dan colocation',
#  'penyampaian usulan implementasi baseline konfigurasi keamanan perangkat tik sebelum proses hosting dan colocation',
#  'penyampaian usulan implementasi baseline konfigurasi keamanan perangkat tik sebelum proses hosting dan colocation',
#  'penyampaian usulan implementasi baseline konfigurasi keamanan perangkat tik sebelum proses hosting dan colocation',
#  'penyampaian laporan pelaksanaan dko dan matriks tindak lanjut dko serta notula rapat dko triwulan ii tahun 2019',
#  'penyampaian laporan pelaksanaan dko dan matriks tindak lanjut dko serta notula rapat dko triwulan ii tahun 2019',
#  'penyampaian laporan pelaksanaan dko dan matriks tindak lanjut dko serta notula rapat dko triwulan ii tahun 2019',
#  'penyampaian laporan pelaksanaan dko dan matriks tindak lanjut dko serta notula rapat dko triwulan ii tahun 2019',
#  'laporan threat monitoring periode juni 2019',
#  'laporan threat monitoring periode juni 2019',
#  'asistensi penyusunan uraian jabatan bagi jabatan pelaksana di lingkungan lembaga national single window',
#  'permohonan pendampingan implementasi aplikasi kemenkeu learning center klc generasi 2',
#  'laporan threat monitoring periode desember 2019',
#  'himbauan terkait penyampaian laporan harta kekayaan dan pajak pajak pribadi melalui alpha',
#  'undangan rapat koordinasi teknis pengembangan jaringan balai diklat keuangan magelang',
#  'sprin plh kepala bidang manajemen layanan tik plh yang ditunjuk tri budianto',
#  'pemberitahuan penambahan perangkat tik dan peralatan elektronik pada kpknl denpasar',
#  'sprin plh kepala bidang manajemen layanan tik plh yang ditunjuk tri budianto',
#  'undangan rapat koordinasi teknis pengembangan jaringan balai diklat keuangan magelang',
#  'ralat peminjaman aula gkn ii denpasar',
#  'himbauan terkait penyampaian laporan harta kekayaan dan pajak pajak pribadi melalui alpha',
#  'penyampaian laporan rekapitulasi utilitas dan availibility intranet bulan november dan desember 2019',
#  'sprin plh kepala bidang manajemen layanan tik plh yang ditunjuk tri budianto',
#  'penyampaian laporan rekapitulasi utilitas dan availibility intranet bulan november dan desember 2019',
#  'himbauan terkait penyampaian laporan harta kekayaan dan pajak pajak pribadi melalui alpha',
#  'penyampaian kendala dan saran perbaikan aplikasi ping',
#  'laporan threat monitoring periode desember 2019',
#  'himbauan terkait penyampaian laporan harta kekayaan dan pajak pajak pribadi melalui alpha',
#  'laporan threat monitoring periode desember 2019',
#  'penyampaian kendala dan saran perbaikan aplikasi ping',
#  'penyampaian laporan rekapitulasi utilitas dan availibility intranet bulan november dan desember 2019',
#  'penyampaian laporan rekapitulasi utilitas dan availibility intranet bulan november dan desember 2019',
#  'penyampaian laporan rekapitulasi utilitas dan availibility intranet bulan november dan desember 2019',
#  'laporan threat monitoring periode desember 2019',
#  'penyampaian laporan rekapitulasi utilitas dan availibility intranet bulan november dan desember 2019',
#  'penyampaian kendala dan saran perbaikan aplikasi ping',
#  'uji coba pengembangan application programming interface api e resources kemenkeu',
#  'langkah langkah strategis pelaksanaan anggaran lingkup unit eselon i sekretariat jenderal kemenkeu tahun anggaran 2020',
#  'surat tugas penyesuaian ds pejabat struktural djpb di sistem bssn',
#  'penyampaian laporan rekapitulasi utilitas dan availibility intranet bulan november dan desember 2019',
#  'penyampaian kendala dan saran perbaikan aplikasi ping',
#  'laporan threat monitoring periode desember 2019',
#  'surat tugas shift februari 2020',
#  'penyampaian laporan rekapitulasi utilitas dan availibility intranet bulan november dan desember 2019',
#  'penyampaian kendala dan saran perbaikan aplikasi ping',
#  'laporan threat monitoring periode desember 2019',
#  'penyampaian kendala dan saran perbaikan aplikasi ping',
#  'penyampaian laporan rekapitulasi utilitas dan availibility intranet bulan november dan desember 2019',
#  'laporan threat monitoring periode desember 2019',
#  'laporan threat monitoring periode desember 2019',
#  'penyampaian kendala dan saran perbaikan aplikasi ping',
#  'langkah langkah strategis pelaksanaan anggaran lingkup unit eselon i sekretariat jenderal kemenkeu tahun anggaran 2020',
#  'penyampaian kendala dan saran perbaikan aplikasi ping',
#  'penyampaian kendala dan saran perbaikan aplikasi ping',
#  'langkah langkah strategis pelaksanaan anggaran lingkup unit eselon i sekretariat jenderal kemenkeu tahun anggaran 2020',
#  'peminjaman aula gkn ii denpasar',
#  'penyampaian kendala dan saran perbaikan aplikasi ping',
#  'laporan threat monitoring periode desember 2019',
#  'penyampaian kendala dan saran perbaikan aplikasi ping',
#  'rapat koordinasi pembahasan operasional jaringan internet direktorat jenderal pajak djp ',
#  'laporan threat monitoring periode desember 2019',
#  'langkah langkah strategis pelaksanaan anggaran lingkup unit eselon i sekretariat jenderal kemenkeu tahun anggaran 2020',
#  'permintaan data dan dokumen pemeriksaan bpk',
#  ...]

# %%
import urllib.parse
import requests
import http.client
import json
kalimat = urllib.parse.quote(list_data[1])
url = "https://translate.googleapis.com/translate_a/single?client=gtx&sl=id&tl=en&dt=t&q="+kalimat
result = requests.get(url)
data = json.loads(result.content)
data[0][0][0]
# Out:
# 'Submission of the Minister of Finance Circular Number Se 29 MK 1 2019 concerning reporting on individual performance dialogues for period I 2020 in the Ministry of Finance'

# %%
temp_list = list_data[0:1001]
result_finish = []
for i in range(0,  1001):
    url = "https://translate.googleapis.com/translate_a/single?client=gtx&sl=id&tl=en&dt=t&q="+list_data[i]
    result = requests.get(url)
    print(result.content)
    data = json.loads(result.content)
    result_finish.append(data[0][0][0])
    print (data)
    print(i)
# Out:
# b'<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">\n<html>\n<head><meta http-equiv="content-type" content="text/html; charset=utf-8"><meta name="viewport" content="initial-scale=1"><title>https://translate.googleapis.com/translate_a/single?client=gtx&amp;sl=id&amp;tl=en&amp;dt=t&amp;q=sprin%20plh%20kepala%20kptik%20bmn%20semarang</title></head>\n<body style="font-family: arial, sans-serif; background-color: #fff; color: #000; padding:20px; font-size:18px;" onload="e=document.getElementById(\'captcha\');if(e){e.focus();}">\n<div style="max-width:400px;">\n<hr noshade size="1" style="color:#ccc; background-color:#ccc;"><br>\n<div style="font-size:13px;">\nOur systems have detected unusual traffic from your computer network.  Please try your request again later.  <a href="#" onclick="document.getElementById(\'infoDiv0\').style.display=\'block\';">Why did this happen?</a><br><br>\n<div id="infoDiv0" style="display:none; background-color:#eee; padding:10px; margin:0 0 15px 0; line-height:1.4em;">\nThis page appears when Google automatically detects requests coming from your computer network which appear to be in violation of the <a href="//www.google.com/policies/terms/">Terms of Service</a>. The block will expire shortly after those requests stop.<br><br>This traffic may have been sent by malicious software, a browser plug-in, or a script that sends automated requests.  If you share your network connection, ask your administrator for help &mdash; a different computer using the same IP address may be responsible.  <a href="//support.google.com/websearch/answer/86640">Learn more</a><br><br>Sometimes you may see this page if you are using advanced terms that robots are known to use, or sending requests very quickly.\n</div><br>\n\nIP address: 36.92.218.74<br>Time: 2020-03-05T07:19:09Z<br>URL: https://translate.googleapis.com/translate_a/single?client=gtx&amp;sl=id&amp;tl=en&amp;dt=t&amp;q=sprin%20plh%20kepala%20kptik%20bmn%20semarang<br>\n</div>\n</div>\n</body>\n</html>\n'
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-45-aca4fd553d01> in <module>
#       5     result = requests.get(url)
#       6     print(result.content)
# ----> 7     data = json.loads(result.content)
#       8     result_finish.append(data[0][0][0])
#       9     print (data)
#
# c:\users\pusintek\appdata\local\programs\python\python38-32\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# c:\users\pusintek\appdata\local\programs\python\python38-32\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\users\pusintek\appdata\local\programs\python\python38-32\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
